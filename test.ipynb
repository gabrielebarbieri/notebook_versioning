# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts.head()
# Out:
# 2000-01-01    0.896759
# 2000-01-02    0.749983
# 2000-01-03   -1.744993
# 2000-01-04    0.534698
# 2000-01-05    0.036726
# Freq: D, dtype: float64

# %%
cum_ts = ts.cumsum()
cum_ts.head()
# Out:
# 2000-01-01    0.896759
# 2000-01-02    1.646742
# 2000-01-03   -0.098251
# 2000-01-04    0.436447
# 2000-01-05    0.473173
# Freq: D, dtype: float64

# %%
cum_ts.plot();
