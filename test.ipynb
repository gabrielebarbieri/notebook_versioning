# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts.head(10)
# Out:
# 2000-01-01    0.437546
# 2000-01-02    0.025890
# 2000-01-03   -0.622634
# 2000-01-04    0.245474
# 2000-01-05    1.392923
# 2000-01-06   -0.894437
# 2000-01-07   -0.147256
# 2000-01-08    0.906578
# 2000-01-09    0.959651
# 2000-01-10    0.621482
# Freq: D, dtype: float64

# %%
cum_ts = ts.cumsum()
cum_ts.head(10)
# Out:
# 2000-01-01    0.437546
# 2000-01-02    0.463436
# 2000-01-03   -0.159198
# 2000-01-04    0.086276
# 2000-01-05    1.479199
# 2000-01-06    0.584762
# 2000-01-07    0.437506
# 2000-01-08    1.344084
# 2000-01-09    2.303735
# 2000-01-10    2.925218
# Freq: D, dtype: float64

# %%
cum_ts.plot();
